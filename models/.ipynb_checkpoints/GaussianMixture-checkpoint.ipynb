# %%
import numpy as np
import matplotlib.pyplot as matplot
import time
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from utils import *

# %%
# importing the dataset
X,y = fetch_openml('mnist_784', version=1, return_X_y=True)
y = y.astype(int)
    
# deleting the columns with unique values and rescaling
# X = X[:, ~np.all(X[1:] == X[:-1], axis=0)]
X = X/255
scaler = StandardScaler()
X = scaler.fit_transform(X)

# check if mean = 0 and std = 1
print((X.mean(axis = 0)).mean())
print((X.std(axis = 0)).mean())
# Out:
# 8.644688463608271e-19
# 0.9170918367346939

# %%
# splitting the data into train, validation and test
X_old, X_new, y_old, y_new = train_test_split(X, y, test_size = 0.4, random_state = 0)
X_train_80, X_test, y_train_80, y_test = train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)
X_train, X_valid , y_train, y_valid = train_test_split(X_train_80, y_train_80, test_size = 0.25, random_state = 0)

# %%
five_train_time = []
five_test_time = []
five_rand = []
five_n_iter = []

seven_train_time = []
seven_test_time = []
seven_rand = []
seven_n_iter = []

ten_train_time = []
ten_test_time = []
ten_rand = []
ten_n_iter = []

twelve_train_time = []
twelve_test_time = []
twelve_rand = []
twelve_n_iter = []

fifteen_train_time = []
fifteen_test_time = []
fifteen_rand = []
fifteen_n_iter = []

for n_comp in [2, 10, 50, 100, 150, 200]: 
    pca = PCA(n_components=n_comp)
    X_train_proj = pca.fit_transform(X_train)
    X_valid_proj = pca.fit_transform(X_valid)
    print('Projected train and validation sets : ',X_train_proj.shape, X_valid_proj.shape)
    
    for k in [5, 7, 10, 12, 15]:
        # for init_par in ['kmeans', 'kmeans++', 'random_from_data']:
            gm = GaussianMixture(n_components=k, covariance_type = 'diag')

            start_train = time.time()
            gm.fit(X_train_proj)
            time_train = time.time() - start_train

            start_test = time.time()
            labels = gm.predict(X_valid_proj)
            time_test = time.time() - start_test

            rand = rand_index(y_valid, labels)

            print(f'n_comp : {n_comp} --- n_clusters : {k} --- rand index : {rand} --- n_iter : {gm.n_iter_} --- converged : {gm.converged_}')
            print('Train time : ', time_train)
            print('Test_time : ', time_test)

            if k == 5:
                five_train_time.append(time_train)
                five_test_time.append(time_test)
                five_rand.append(rand)
                five_n_iter.append(gm.n_iter_)
            else:
                if k == 7:
                    seven_train_time.append(time_train)
                    seven_test_time.append(time_test)
                    seven_rand.append(rand)
                    seven_n_iter.append(gm.n_iter_)
                else:
                    if k == 10:
                        ten_train_time.append(time_train)
                        ten_test_time.append(time_test)
                        ten_rand.append(rand)
                        ten_n_iter.append(gm.n_iter_)
                    else:
                        if k == 12:
                            twelve_train_time.append(time_train)
                            twelve_test_time.append(time_test)
                            twelve_rand.append(rand)
                            twelve_n_iter.append(gm.n_iter_)
                        else:
                            fifteen_train_time.append(time_train)
                            fifteen_test_time.append(time_test)
                            fifteen_rand.append(rand)
                            fifteen_n_iter.append(gm.n_iter_)
# Out:
# Projected train and validation sets :  (16800, 2) (5600, 2)
# n_comp : 2 --- n_clusters : 5 --- rand index : 0.7476236190135994 --- n_iter : 9 --- converged : True
# Train time :  0.12622618675231934
# Test_time :  0.0
# n_comp : 2 --- n_clusters : 7 --- rand index : 0.8086496313117139 --- n_iter : 19 --- converged : True
# Train time :  0.2686281204223633
# Test_time :  0.0
# n_comp : 2 --- n_clusters : 10 --- rand index : 0.8371633965248897 --- n_iter : 25 --- converged : True
# Train time :  0.4136230945587158
# Test_time :  0.0
# n_comp : 2 --- n_clusters : 12 --- rand index : 0.8467489730308984 --- n_iter : 20 --- converged : True
# Train time :  0.4042031764984131
# Test_time :  0.0
# n_comp : 2 --- n_clusters : 15 --- rand index : 0.8514009517005587 --- n_iter : 14 --- converged : True
# Train time :  0.4643700122833252
# Test_time :  0.0
# Projected train and validation sets :  (16800, 10) (5600, 10)
# n_comp : 10 --- n_clusters : 5 --- rand index : 0.6390151302528513 --- n_iter : 36 --- converged : True
# Train time :  0.5717489719390869
# Test_time :  0.0
# n_comp : 10 --- n_clusters : 7 --- rand index : 0.7278113438624244 --- n_iter : 18 --- converged : True
# Train time :  0.3039369583129883
# Test_time :  0.015629053115844727
# n_comp : 10 --- n_clusters : 10 --- rand index : 0.7908936544791162 --- n_iter : 16 --- converged : True
# Train time :  0.34381961822509766
# Test_time :  0.0
# n_comp : 10 --- n_clusters : 12 --- rand index : 0.8244393769295537 --- n_iter : 17 --- converged : True
# Train time :  0.41764402389526367
# Test_time :  0.0
# n_comp : 10 --- n_clusters : 15 --- rand index : 0.8489382032505804 --- n_iter : 16 --- converged : True
# Train time :  0.47446775436401367
# Test_time :  0.010508060455322266
# Projected train and validation sets :  (16800, 50) (5600, 50)
# n_comp : 50 --- n_clusters : 5 --- rand index : 0.5645651646977776 --- n_iter : 34 --- converged : True
# Train time :  0.7800710201263428
# Test_time :  0.0
# n_comp : 50 --- n_clusters : 7 --- rand index : 0.6084147041563545 --- n_iter : 29 --- converged : True
# Train time :  0.8410546779632568
# Test_time :  0.0
# n_comp : 50 --- n_clusters : 10 --- rand index : 0.6448937948102977 --- n_iter : 24 --- converged : True
# Train time :  0.8458583354949951
# Test_time :  0.0
# n_comp : 50 --- n_clusters : 12 --- rand index : 0.598929592018983 --- n_iter : 44 --- converged : True
# Train time :  1.3595390319824219
# Test_time :  0.0
# n_comp : 50 --- n_clusters : 15 --- rand index : 0.6062105478019034 --- n_iter : 82 --- converged : True
# Train time :  2.731675386428833
# Test_time :  0.015622138977050781
# Projected train and validation sets :  (16800, 100) (5600, 100)
# n_comp : 100 --- n_clusters : 5 --- rand index : 0.6122627765162146 --- n_iter : 34 --- converged : True
# Train time :  1.3673996925354004
# Test_time :  0.0
# n_comp : 100 --- n_clusters : 7 --- rand index : 0.6302162375934478 --- n_iter : 38 --- converged : True
# Train time :  1.7613310813903809
# Test_time :  0.0
# n_comp : 100 --- n_clusters : 10 --- rand index : 0.6068737402087108 --- n_iter : 42 --- converged : True
# Train time :  1.8862495422363281
# Test_time :  0.0
# n_comp : 100 --- n_clusters : 12 --- rand index : 0.5981489679279464 --- n_iter : 36 --- converged : True
# Train time :  1.7701749801635742
# Test_time :  0.0
# n_comp : 100 --- n_clusters : 15 --- rand index : 0.6644540479167198 --- n_iter : 79 --- converged : True
# Train time :  3.7779793739318848
# Test_time :  0.0
# Projected train and validation sets :  (16800, 150) (5600, 150)
# n_comp : 150 --- n_clusters : 5 --- rand index : 0.6304588829637946 --- n_iter : 52 --- converged : True
# Train time :  3.500800132751465
# Test_time :  0.013514518737792969
# n_comp : 150 --- n_clusters : 7 --- rand index : 0.6387318526267446 --- n_iter : 47 --- converged : True
# Train time :  2.6854968070983887
# Test_time :  0.0
# n_comp : 150 --- n_clusters : 10 --- rand index : 0.6596824050213048 --- n_iter : 37 --- converged : True
# Train time :  2.566549062728882
# Test_time :  0.015625715255737305
# n_comp : 150 --- n_clusters : 12 --- rand index : 0.6839663970606996 --- n_iter : 27 --- converged : True
# Train time :  2.18530535697937
# Test_time :  0.0
# n_comp : 150 --- n_clusters : 15 --- rand index : 0.6468129512923226 --- n_iter : 41 --- converged : True
# Train time :  7.029469728469849
# Test_time :  0.006509304046630859
# Projected train and validation sets :  (16800, 200) (5600, 200)
# n_comp : 200 --- n_clusters : 5 --- rand index : 0.6430658535963054 --- n_iter : 44 --- converged : True
# Train time :  4.79477596282959
# Test_time :  0.003509044647216797
# n_comp : 200 --- n_clusters : 7 --- rand index : 0.6957046538922766 --- n_iter : 21 --- converged : True
# Train time :  3.092285633087158
# Test_time :  0.015622615814208984
# n_comp : 200 --- n_clusters : 10 --- rand index : 0.7175577909320542 --- n_iter : 30 --- converged : True
# Train time :  4.106969833374023
# Test_time :  0.01562952995300293
# n_comp : 200 --- n_clusters : 12 --- rand index : 0.6696003112800756 --- n_iter : 37 --- converged : True
# Train time :  4.411178350448608
# Test_time :  0.015618324279785156
# n_comp : 200 --- n_clusters : 15 --- rand index : 0.724359898451254 --- n_iter : 96 --- converged : True
# Train time :  9.80050253868103
# Test_time :  0.015624761581420898

# %%
n_comp = [2, 10, 50, 100, 150, 200]

matplot.subplots(figsize=(10, 5))
matplot.plot(n_comp, five_train_time,'--x' ,color='red' , label="k = 5")
matplot.plot(n_comp, seven_train_time,'--x', color = 'green' ,label="k = 7")
matplot.plot(n_comp, ten_train_time,'--x' ,color = 'purple', label="k = 10")
matplot.plot(n_comp, twelve_train_time,'--x' , color = 'black', label="k = 12")
matplot.plot(n_comp, fifteen_train_time,'--x' , color = 'orange', label="k = 15")
matplot.grid(True)
matplot.xlabel("Number of components")
matplot.ylabel("Train time (s)")
matplot.legend()
matplot.title('Train time versus number of PCA components')
matplot.show()

# %%
n_comp = [2, 10, 50, 100, 150, 200]

matplot.subplots(figsize=(10, 5))
matplot.plot(n_comp, five_test_time,'--x' ,color='red' , label="k = 5")
matplot.plot(n_comp, seven_test_time,'--x' , color = 'green', label="k = 7")
matplot.plot(n_comp, ten_test_time,'--x' , color = 'purple', label="k = 10")
matplot.plot(n_comp, twelve_test_time,'--x' , color = 'black', label="k = 12")
matplot.plot(n_comp, fifteen_test_time,'--x' , color = 'orange', label="k = 15")
matplot.grid(True)
matplot.xlabel("Number of components")
matplot.ylabel("Test time (s)")
matplot.legend()
matplot.title('Test time versus number of PCA components')
matplot.show()

# %%
n_comp = [2, 10, 50, 100, 150, 200]

matplot.subplots(figsize=(10, 5))
matplot.plot(n_comp, five_rand,'--x' ,color='red' , label="k = 5")
matplot.plot(n_comp, seven_rand,'--x' , color = 'green', label="k = 7")
matplot.plot(n_comp, ten_rand,'--x' , color = 'purple', label="k = 10")
matplot.plot(n_comp, twelve_rand,'--x' , color = 'black', label="k = 12")
matplot.plot(n_comp, fifteen_rand,'--x' , color = 'orange', label="k = 15")
matplot.grid(True)
matplot.xlabel("Number of components")
matplot.ylabel("Rand index")
matplot.legend()
matplot.title('Rand index versus number of PCA components')
matplot.show()

# %%
n_comp = [2, 10, 50, 100, 150, 200]

matplot.subplots(figsize=(10, 5))
matplot.plot(n_comp, five_n_iter,'--x' ,color='red' , label="k = 5")
matplot.plot(n_comp, seven_n_iter,'--x' , color = 'green', label="k = 7")
matplot.plot(n_comp, ten_n_iter,'--x' , color = 'purple', label="k = 10")
matplot.plot(n_comp, twelve_n_iter,'--x' , color = 'black', label="k = 12")
matplot.plot(n_comp, fifteen_n_iter,'--x' , color = 'orange', label="k = 15")
matplot.grid(True)
matplot.xlabel("Number of components")
matplot.ylabel("Number of iteratios")
matplot.legend()
matplot.title('Number of iterations versus number of PCA components')
matplot.show()

# %% [markdown]
# Executing the best model, i.e. n_comp = 2 and k = 15.

# %%
pca = PCA(n_components=2)
X_train_proj = pca.fit_transform(X_train)
X_test_proj = pca.fit_transform(X_test)

gm = GaussianMixture(n_components=15, covariance_type = 'diag')

start_train = time.time()
gm.fit(X_train_proj)
time_train = time.time() - start_train

start_test = time.time()
labels = gm.predict(X_test_proj)
time_test = time.time() - start_test

rand = rand_index(y_test, labels)

print(f'n_clusters : 15 --- rand index : {rand} --- n_iter : {gm.n_iter_} --- converged : {gm.converged_}')
print('Train time : ', time_train)
print('Test_time : ', time_test)
# Out:
# n_clusters : 15 --- rand index : 0.8394120761360447 --- n_iter : 12 --- converged : True
# Train time :  0.5396313667297363
# Test_time :  0.0

# %% [markdown]
# Visualization of the clustering results for n_comp = 2 and k = 15.
